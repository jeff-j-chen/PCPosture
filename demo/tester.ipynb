# %%
import numpy as np


t = np.load("/home/jeff/Documents/Code/Final_Project/output/keypoints.npy")
print(t[0][0])
# Out:
# [[318.89243  598.38934 ]
#  [221.32013  598.38934 ]
#  [221.32013  598.38934 ]
#  [221.32013  598.38934 ]
#  [416.46472  598.38934 ]
#  [416.46472  598.38934 ]
#  [416.46472  598.38934 ]
#  [279.27972  469.54388 ]
#  [309.71896  293.16315 ]
#  [338.90726  192.46353 ]
#  [321.3943    88.01114 ]
#  [441.48328  338.19653 ]
#  [566.576    523.33374 ]
#  [611.6093   578.3745  ]
#  [131.25339  343.20023 ]
#  [ 46.190346 583.37823 ]
#  [ 36.18293  583.37823 ]]
